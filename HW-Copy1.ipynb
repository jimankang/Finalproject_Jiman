# %% [markdown]
# # Intestine Transplant
# ![](https://optn.transplant.hrsa.gov/media/data/organ_intestine.gif)
#
# ### About the Intestine
# #### The descending colon is the middle part of the colon located on the left side of the abdomen. The large intestine goes from the cecum to the rectum. Measuring about twenty feet, the small intestine is where most digestion occurs.
#
# #### Reference: United Network for Organ Sharing (UNOS)

# %% [markdown]
# ![](https://myhealth.alberta.ca/Health/_layouts/15/healthwise/media/medical/hw/hwkb17_007_11.jpg)
#
# ### Transplant procedure
#
# #### For an intestinal transplant, the recipient's diseased intestine is removed and replaced with the donated intestine. Most intestine transplants involve a whole organ from a deceased donor and most intestine transplants are performed in conjunction with a liver transplant.
#
# ### Difficulty in Intestinial Transplant
# #### The intestine has been more difficult to transplant than other solid organs and some of the possible reasons include:
#
# #### the large number of white cells in the bowel provides a strong stimulus for rejection
# #### the large number of bacteria in the gut increases the risk of infection after transplantation

# %%
import matplotlib.pyplot as plt
labels ='Liver','Kidney', 'Kidney/Pancreas', 'Pancreas', 'Heart', 'Lung', 'Intestine'
sizes = [21.6, 58.9, 3.2, 1.2, 9.6, 4.9, 0.4]
colors =['blue', 'green', 'orange','red', 'yellow', 'pink', 'purple']
plt.figure(figsize =(7,7))
plt.pie(sizes, labels=labels, colors=colors, shadow =True, startangle =120)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
transplant_data = pd.read_csv("book1.csv",index_col =0)
print(transplant_data)
# Out:
#        Recipient Blood Type   Years  Number Functioning Alive  Survival Rate  \
# Region
# U.S.                      O  1 Year                       191           80.5
# U.S.                      A  1 Year                       109           69.2
# U.S.                      B  1 Year                        54           76.4
# U.S.                     AB  1 Year                        16           72.7
# U.S.                      O  3 Year                       151           64.8
# U.S.                      A  3 Year                        90           53.9
# U.S.                      B  3 Year                        31           57.0
# U.S.                     AB  3 Year                        15           57.7
# U.S.                      O  5 Year                       145           53.7
# U.S.                      A  5 Year                       117           47.3
# U.S.                      B  5 Year                        33           41.8
# U.S.                     AB  5 Year                        12           49.7
#
#        95% Confidence Interval
# Region
# U.S.              (75.0, 85.0)
# U.S.              (61.4, 75.7)
# U.S.              (64.8, 84.6)
# U.S.              (49.1, 86.7)
# U.S.              (58.3, 70.5)
# U.S.              (46.2, 61.0)
# U.S.              (43.2, 68.5)
# U.S.              (36.8, 73.9)
# U.S.              (47.6, 59.3)
# U.S.              (41.1, 53.3)
# U.S.              (31.1, 52.0)
# U.S.              (29.5, 67.0)

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
# %matplotlib inline
survival_rate1 = [80.5, 69.2, 76.4, 72.7]
survival_rate2 = [64.8, 53.9, 57.0, 57.7]
survival_rate3 = [53.7, 47.3, 41.8, 49.7]
years= [1,3,5]
for i in range(0,4):
    plt.plot(years, 
             [survival_rate1[i],
              survival_rate2[i],
              survival_rate3[i]],
              '-o')
blue = mpatches.Patch(color ='blue', label='O')
green = mpatches.Patch(color ='green', label='B')
red =mpatches.Patch(color = 'red', label= 'AB')
orange =mpatches.Patch(color ='orange', label= 'A')
plt.legend(handles= [blue, green, red, orange])
plt.title('transplant survival(Intestine)', fontsize=20)
plt.show()

# %%
Tx_data =pd.read_csv("ILC Demographics.HW1.csv", sep=",")


print(Tx_data.head())
Tx_data.head()
# Out:
#   Last First     MRN      Race Sex Genotype  Age at Tx (yrs) Date of SBTx  \
# 0  XXX   XXX  720XXX     White   F       WT              3.9     9/3/2015
# 1  XXX   XXX  632XXX     White   M       WT             20.7    9/18/2015
# 2  XXX   XXX  734XXX     White   F       WT             54.6    9/23/2015
# 3  XXX   XXX  226XXX  Hispanic   M       WT              1.7   11/19/2015
# 4  XXX   XXX  653XXX     White   F       WT             54.1   11/22/2015
#
#    Operation                            Primary Path      ...       GVHD date  \
# 0  L/Panc/SB                           Gastroschisis      ...             NaN
# 1         SB          Mitochodrial motility disorder      ...             NaN
# 2         SB  Mesenteric arterial thrombosis/embolus      ...             NaN
# 3  L/Panc/SB         Microvillious inclusion disease      ...             NaN
# 4         SB                Mass resection 2/2 tumor      ...             NaN
#
#   Death  Date of Death Cause of Death 2_4wk_NCR_ILC1 2_4wk_NCR_ILC3  \
# 0    No            NaN            NaN           83.9            0.0
# 1    No            NaN            NaN           90.0            1.2
# 2    No            NaN            NaN            NaN            NaN
# 3    No            NaN            NaN            NaN            NaN
# 4    No            NaN            NaN            NaN            NaN
#
#   2_4M_NCR_ILC1 2_4M_NCR_ILC3  4_6M_NCR_ILC1  4_6M_NCR_ILC3
# 0          88.9          0.00           92.9           2.17
# 1          33.0          3.85           94.4           4.00
# 2           NaN           NaN            NaN            NaN
# 3           NaN           NaN            NaN            NaN
# 4           NaN           NaN            NaN            NaN
#
# [5 rows x 24 columns]
#   Last First     MRN      Race Sex Genotype  Age at Tx (yrs) Date of SBTx  \
# 0  XXX   XXX  720XXX     White   F       WT              3.9     9/3/2015
# 1  XXX   XXX  632XXX     White   M       WT             20.7    9/18/2015
# 2  XXX   XXX  734XXX     White   F       WT             54.6    9/23/2015
# 3  XXX   XXX  226XXX  Hispanic   M       WT              1.7   11/19/2015
# 4  XXX   XXX  653XXX     White   F       WT             54.1   11/22/2015
#
#    Operation                            Primary Path      ...       GVHD date  \
# 0  L/Panc/SB                           Gastroschisis      ...             NaN
# 1         SB          Mitochodrial motility disorder      ...             NaN
# 2         SB  Mesenteric arterial thrombosis/embolus      ...             NaN
# 3  L/Panc/SB         Microvillious inclusion disease      ...             NaN
# 4         SB                Mass resection 2/2 tumor      ...             NaN
#
#   Death  Date of Death Cause of Death 2_4wk_NCR_ILC1 2_4wk_NCR_ILC3  \
# 0    No            NaN            NaN           83.9            0.0
# 1    No            NaN            NaN           90.0            1.2
# 2    No            NaN            NaN            NaN            NaN
# 3    No            NaN            NaN            NaN            NaN
# 4    No            NaN            NaN            NaN            NaN
#
#   2_4M_NCR_ILC1 2_4M_NCR_ILC3  4_6M_NCR_ILC1  4_6M_NCR_ILC3
# 0          88.9          0.00           92.9           2.17
# 1          33.0          3.85           94.4           4.00
# 2           NaN           NaN            NaN            NaN
# 3           NaN           NaN            NaN            NaN
# 4           NaN           NaN            NaN            NaN
#
# [5 rows x 24 columns]

# %%
#gender = {"M":0, "F":1}
#Tx_data.Sex = [gender[item] for item in Tx_data.Sex]
Tx_data.Sex[Tx_data.Sex =="M"] =1
Tx_data.Sex[Tx_data.Sex =="F"] =2
Tx_data.Rejection[Tx_data.Rejection == "No"] =0
Tx_data.Rejection[Tx_data.Rejection =="Yes"] =1
Tx_data.Death[Tx_data.Death =="No"] =0
Tx_data.Death[Tx_data.Death =="Yes"] =1
Tx_data.head()
# Out:
# C:\Users\Jiman\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Jiman\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Jiman\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Jiman\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   Last First     MRN      Race Sex Genotype  Age at Tx (yrs) Date of SBTx  \
# 0  XXX   XXX  720XXX     White   2       WT              3.9     9/3/2015
# 1  XXX   XXX  632XXX     White   1       WT             20.7    9/18/2015
# 2  XXX   XXX  734XXX     White   2       WT             54.6    9/23/2015
# 3  XXX   XXX  226XXX  Hispanic   1       WT              1.7   11/19/2015
# 4  XXX   XXX  653XXX     White   2       WT             54.1   11/22/2015
#
#    Operation                            Primary Path      ...       GVHD date  \
# 0  L/Panc/SB                           Gastroschisis      ...             NaN
# 1         SB          Mitochodrial motility disorder      ...             NaN
# 2         SB  Mesenteric arterial thrombosis/embolus      ...             NaN
# 3  L/Panc/SB         Microvillious inclusion disease      ...             NaN
# 4         SB                Mass resection 2/2 tumor      ...             NaN
#
#   Death  Date of Death Cause of Death 2_4wk_NCR_ILC1 2_4wk_NCR_ILC3  \
# 0     0            NaN            NaN           83.9            0.0
# 1     0            NaN            NaN           90.0            1.2
# 2     0            NaN            NaN            NaN            NaN
# 3     0            NaN            NaN            NaN            NaN
# 4     0            NaN            NaN            NaN            NaN
#
#   2_4M_NCR_ILC1 2_4M_NCR_ILC3  4_6M_NCR_ILC1  4_6M_NCR_ILC3
# 0          88.9          0.00           92.9           2.17
# 1          33.0          3.85           94.4           4.00
# 2           NaN           NaN            NaN            NaN
# 3           NaN           NaN            NaN            NaN
# 4           NaN           NaN            NaN            NaN
#
# [5 rows x 24 columns]

# %%
import seaborn as sns
sns.set()
Tx_data.hist(figsize=(10,10))
plt.show()

# %%
#Tx_data['No Rejection'] = 1 + Tx_data['Rejection']

#Tx_data.groupby('Sex').agg('sum')[['No Rejection','Rejection']].plot(kind='bar', figsize=(25, 7),
                                                          #stacked=True, colors=['g', 'r'])

import matplotlib.patches as mpatches    
def bar_chart(feature):
    Not_Rejection = Tx_data[Tx_data['Rejection']==0][feature].value_counts()
    Rejection = Tx_data[Tx_data['Rejection']==1][feature].value_counts()
    df = pd.DataFrame([Not_Rejection,Rejection])
    df.index = ['Not_Rejection','Rejection']
    df.plot(kind='bar',stacked=True, figsize=(8,4), color=['g', 'r'])
    plt.ylabel('Patient Numbers', fontsize=15)
    plt.title('Rejection vs Sex', fontsize=18)
    plt.legend(('M', 'F'))

# %%
bar_chart('Sex')

# %%
x1 =Tx_data['2_4wk_NCR_ILC1']
x2 =Tx_data['2_4M_NCR_ILC1']
x3 =Tx_data['4_6M_NCR_ILC1']
y1 =Tx_data['2_4wk_NCR_ILC3']
y2 =Tx_data['2_4M_NCR_ILC3']
y3 =Tx_data['4_6M_NCR_ILC3']


plt.scatter(x1, y1, c='r', label ='2-4wks')
plt.scatter(x2, y2, c='g', label ='2-4M')
plt.scatter(x3, y3, c='b', label ='4-6M')


plt.xlabel('NCR+ILC1')  
plt.ylabel('NCR+ILC3') 
plt.title('NCR+ILC1 vs NCR+ILC3', fontsize =18)
plt.legend()
plt.show()

# %%
Tx_data.plot.scatter(x='2_4wk_NCR_ILC1', y='2_4wk_NCR_ILC3', c='r')
#Tx_data.plot.scatter(x='2_4M_NCR_ILC1', y='2_4M_NCR_ILC3', c='g')
#Tx_data.plot.scatter(x='4_6M_NCR_ILC1', y='4_6M_NCR_ILC3', c='b')

# %%
sns.lmplot(x='2_4wk_NCR_ILC1', y='2_4wk_NCR_ILC3', data=Tx_data)

# %%
sns.lmplot(x='2_4wk_NCR_ILC1', y='2_4wk_NCR_ILC3', hue='Sex',data=Tx_data)

# %%
# Subset data into feature and target

X = Tx_data[['2_4wk_NCR_ILC1']].values
y = Tx_data[['2_4wk_NCR_ILC3']].values
    
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)

# Plot scatter plot of data
plt.scatter(X, y)

# Create the prediction space
prediction_space = np.linspace(min(X), max(X)).reshape(-1,1)

# Compute predictions over the prediction space: y_pred
y_pred = reg.predict(prediction_space)


# Plot regression line
plt.plot(prediction_space, y_pred, color='black', linewidth=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-e4279fe101e0> in <module>()
#       7
#       8 lr = LinearRegression()
# ----> 9 lr.fit(X, y)
#      10
#      11 # Plot scatter plot of data
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     510         n_jobs_ = self.n_jobs
#     511         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 512                          y_numeric=True, multi_output=True)
#     513
#     514         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# Print R^2 
lr = LinearRegression()
print(lr.score(X, y))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-20-1d6acdbacdf9> in <module>()
#       1 # Print R^2
#       2 lr = LinearRegression()
# ----> 3 print(lr.score(X, y))
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     384
#     385         from .metrics import r2_score
# --> 386         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     387                         multioutput='variance_weighted')
#     388
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     266             Returns predicted values.
#     267         """
# --> 268         return self._decision_function(X)
#     269
#     270     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     247
#     248     def _decision_function(self, X):
# --> 249         check_is_fitted(self, "coef_")
#     250
#     251         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# C:\Users\Jiman\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     688     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
#     689         # FIXME NotFittedError_ --> NotFittedError in 0.19
# --> 690         raise _NotFittedError(msg % {'name': type(estimator).__name__})
#     691
#     692
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
# Print regression coefficient(s)
print(lr.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-949ae0c0f6e8> in <module>()
#       1 # Print regression coefficient(s)
# ----> 2 print(lr.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'
